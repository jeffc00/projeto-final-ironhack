# %%
import gc
import string
from functools import partial
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import re
import requests
from datetime import datetime as dt, timedelta, date, time
from tqdm import tqdm
from bs4 import BeautifulSoup
import joblib
import spacy
from nltk.util import ngrams
import multiprocessing
from sklearn.base import TransformerMixin
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV, train_test_split, cross_validate, cross_val_score, learning_curve
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_score, recall_score, plot_precision_recall_curve
from sklearn.preprocessing import FunctionTransformer
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings

warnings.filterwarnings("ignore")

# %%
def get_stock_data():
    pass

def update_stock_data():
    pass

# %%
def load_stock_data(ticker='TSLA'):
    '''Load csv file to a pandas dataframe.
    
    Args:
        symbol: company's symbol
        
    Returns:
        A pandas dataframe containing the stock's data.
    '''
    
    df = pd.read_csv(f'data/{ticker}.csv')
    df.columns = ['date', 'close', 'open', 'high', 'low', 'volume', 'pct_change']
    
    return df

# %%
def clean_stock_data(df):
    '''Clean dataframe: change variables to appropriate dtypes.
    
    Args:
        df: pandas dataframe
        
    Returns:
        A cleaned dataframe ready to be modeled.
    '''
    
    df['date'] = pd.to_datetime(df['date'], format='%b %d, %Y')
    
    cols_num = ['close', 'open', 'high', 'low']
    df[cols_num] = df[cols_num].astype(float)
    
    df['volume'] = df['volume'].str.replace('.', '').str.replace('M', '000000')
    df['volume'] = df['volume'].str.replace('.', '').str.replace('K', '000')
    df['volume'] = df['volume'].astype(int)
    
    df['pct_change'] = df['pct_change'].str.rstrip('%')
    df['pct_change'] = df['pct_change'].astype(float) / 100
    
    return df

# %%
def get_news_data(page):
    '''Get news on stocks from the page in Investing.com website.
    
    Args:
        page: the page from which the news will be extracted
    
    Returns:
        A pandas dataframe for the page containing datetime, title and contents from the news.
    '''
    
    url_investing = 'https://investing.com'
    title_ls = []
    dt_ls = []
    text_ls = []
    url = f'/equities/tesla-motors-news/{page}'
    result = requests.get(url_investing + url,
                          headers={'User-Agent': 'Chrome/79.0.3945.130'})
    soup = BeautifulSoup(result.content, 'html.parser')

    anchors_ls = [art.find('a') for art in soup.find_all('article')]
    for a in anchors_ls:
        if a['href'].startswith('/news'):
            title_ls.append(a.find('img').get('alt'))
            url_contents = scraper(url_investing + a['href'])
            dt_ls.append(url_contents[0])
            text_ls.append(url_contents[1])

    news_data = {'datetime': dt_ls, 'title': title_ls, 'text': text_ls}
    news_df = pd.DataFrame(news_data)
    
    joblib.dump(news_df, f'data/news tesla/news_df{page}.pkl')
    
    return news_df

# %%
def save_news_df(initial_pg, final_pg):
    '''Parallelizes the extraction of news data using the get_news_data function.
    
    Args:
        initial_pg: initial page
        final_pg: final page (not inclusive)
    
    Returns:
        A pandas dataframe containing all the news from 2016 until today.
    '''
    
    pool = multiprocessing.Pool()
    df_ls = pool.map(get_news_data, range(initial_pg, final_pg))
    pool.terminate()
    pool.join()
    
    news_df = (pd.concat(df_ls, axis=0)
               .drop_duplicates()
               .sort_values('datetime', ascending=False)
               .reset_index(drop=True))
    
    joblib.dump(news_df, 'data/news_tesla_df.pkl')

# %%
def load_news_df():
    news_df = pd.DataFrame(columns=['datetime', 'title', 'text'])
    for i in range(7, 384):
        news_df = pd.concat([news_df, joblib.load(f'data/news tesla/news_df{i}.pkl')])
        
    return news_df.drop_duplicates().sort_values('datetime', ascending=False).reset_index(drop=True)

# %%
def clean_news_df(df):
    '''Clean and aggregate news by date. Given a date, only news realeased before market closure are aggregated.
    
    Args:
        df: pandas dataframe containing all the news ordered by datetime
        
    Returns:
        A pandas dataframe with all the news aggregated by date.
    '''
    
    # we want to work with news starting in 2015
    df = (df[(df['datetime'] <= dt(2020, 2, 3, 16)) & (df['datetime'] >= dt(2015, 1, 2))]
          .reset_index(drop=True))
    
    start = date(2015, 1, 1)
    end = date(2020, 2, 3)
    date_span = [end - timedelta(days=d) for d in range(0, (end - start).days)]

    date_ls = []
    news_ls = []
    for d in date_span:
        date_ls.append(d)

        window = ((df['datetime'] < dt.combine(d, time(16))) &\
                  (df['datetime'] >= dt.combine(d - timedelta(days=1), time(16))))
        news_ls.append(list(df.loc[window, 'text'].values))

    agg_news = {'date': date_ls, 'news': news_ls}
    agg_news_df = pd.DataFrame(agg_news)
    agg_news_df['date'] = pd.to_datetime(agg_news_df['date'], infer_datetime_format=True)
    
    return agg_news_df

# %%
tsla_df = clean_stock_data(load_stock_data())
agg_news_df = clean_news_df(load_news_df())
full_df = tsla_df.merge(agg_news_df, on='date').sort_values('date').reset_index(drop=True)

# %%
full_df['bullish'] = 0
full_df['bullish'] = (full_df['close'] > full_df['open']).astype(int)

# %%
cols_to_drop = ['date', 'close', 'open', 'high', 'low', 'volume', 'pct_change', 'bullish']
X = full_df.drop(cols_to_drop, axis=1)
y = full_df['bullish']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, shuffle=False)
test_idx = X_test.index
X_test.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def append_ngrams(tokens_ls):
    bigrams_ls = [' '.join(bigram) for bigram in list(ngrams(tokens_ls, 2))]
    trigrams_ls = [' '.join(trigram) for trigram in list(ngrams(tokens_ls, 3))]
    return tokens_ls + bigrams_ls + trigrams_ls

# %%
def clean_tokens(tokens_ls):
    bad_token = [' ', '  ', '\n', ' \n', '  \n']
    return [token for token in tokens_ls if token not in bad_token]

# %%
def news_tokenizer(df):
    tokens = []
    for news_ls in tqdm(df['news']):
        news_tokens = []
        for news in news_ls:
            doc = nlp(news)
            for sent in doc.sents:
                sent_tokens = [token.lemma_ for token in sent if not (token.is_stop or token.is_punct)]
                sent_tokens_ext = append_ngrams(clean_tokens(sent_tokens))
                news_tokens += sent_tokens_ext
#                 sent_tokens = clean_tokens(sent_tokens)
#                 news_tokens += sent_tokens
        tokens.append(news_tokens)
        
    df['tokens'] = tokens
    
    return df

# %%
def count_words(df, w):
    count = {w: []}
    for i in range(len(df)):
        count[w].append(df.loc[i, 'tokens'].count(w))
    return count

# %%
def get_bow(df):
    bow = set()
    for tokens_ls in df['tokens']:
        bow = bow.union(set(tokens_ls))
    return list(bow)

# %%
bow = get_bow(news_tokenizer(X_train))
# Out:
# 100%|██████████| 1024/1024 [01:38<00:00, 10.38it/s]

# %%
def count_matrix(df):
    pool = multiprocessing.Pool()
    func = partial(count_words, df)
    word_counts = pool.map(func, bow)
    pool.terminate()
    pool.join()
    
    count_dict = {list(wc.keys())[0]:  pd.arrays.SparseArray(list(wc.values())[0]) for wc in word_counts}
    
    return pd.DataFrame(count_dict)

# %%
tokens_transformer = FunctionTransformer(news_tokenizer)
cmat_transformer = FunctionTransformer(count_matrix)

sub_pipe = Pipeline([('tokenizer', tokens_transformer),
                     ('count_mat', cmat_transformer),
                     ('tfidf', TfidfTransformer()),
                     ('tsvd', TruncatedSVD(n_components=508))])

X_train_transf = sub_pipe.fit_transform(X_train)
X_test_transf = sub_pipe.transform(X_test)
# Out:
# 100%|██████████| 1024/1024 [01:38<00:00, 10.44it/s]
# 100%|██████████| 257/257 [00:44<00:00,  5.82it/s]

# %%
idx = range(508)
var_exp = np.cumsum(sub_pipe.named_steps['tsvd'].explained_variance_ratio_)
print('explained variance ratio using 508 components: {:.3f}%'.format(100 * var_exp[-1]))
plt.plot(idx, var_exp);
# Out:
# explained variance ratio using 508 components: 78.896%

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
logr_clf = LogisticRegression(random_state=42, n_jobs=-1)

logr_params = {'penalty': ['l1', 'l2', 'elasticnet'],
               'C': ss.uniform(0, 1),
               'l1_ratio': ss.uniform(0, 1)}

# %%
svm_clf = SVC(random_state=42)

svm_params = {'C': ss.uniform(0, 1),
              'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
              'degree': [1, 2],
              'coef0': ss.uniform(-10, 10)}

# %%
lgbm_clf = LGBMClassifier(max_depth=1, random_state=42, n_jobs=-1)

lgbm_params = {'boosting_type': ['gbdt', 'dart', 'goss', 'rf'],
               'learning_rate': ss.uniform(0, 1),
               'n_estimators': range(1,500),
               'subsample': ss.uniform(0.001, 1),
               'subsample_freq': range(1,101),
               'colsample_bytree': ss.uniform(0.001, 1),
               'reg_alpha': ss.uniform(0, 1),
               'reg_lambda': ss.uniform(0, 1)}

# %%
xgb_clf = XGBClassifier(max_depth=1, random_state=42, n_jobs=-1)

xgb_params = {'learning_rate': ss.uniform(0, 1),
              'boster': ['gbtree', 'gblinear', 'dart'],
              'subsample': ss.uniform(0.001, 1),
              'colsample_bytree': ss.uniform(0.001, 1),
              'colsample_bylevel': ss.uniform(0.001, 1),
              'colsample_bynode': ss.uniform(0.001, 1),
              'reg_alpha': ss.uniform(0, 1),
              'reg_lambda': ss.uniform(0, 1),
              'num_parallel_tree': range(1,500)}

# %%
models = {'logr': [logr_clf, logr_params],
          'svm': [svm_clf, svm_params],
          'lgbm': [lgbm_clf, lgbm_params],
          'xgb': [xgb_clf, xgb_params]}

# %%
best_estimators = {}
for m in tqdm(models.keys()):
    rscv = RandomizedSearchCV(models[m][0],
                              models[m][1],
                              n_iter=500,
#                               n_iter=100,
                              scoring='precision',
                              n_jobs=-1,
                              cv=tscv,
                              verbose=True,
                              random_state=42)

    rscv.fit(X_train_transf, y_train)
    best_estimators[m] = rscv.best_estimator_
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 1440 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed: 12.3min finished
#  25%|██▌       | 1/4 [13:45<41:16, 825.48s/it][Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 824 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done 1274 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1824 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2474 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed:  2.5min finished
#  50%|█████     | 2/4 [16:15<20:45, 622.79s/it][Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed:  3.2min finished
#  75%|███████▌  | 3/4 [19:27<08:13, 493.72s/it]
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed: 39.8min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed: 60.4min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed: 95.8min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed: 123.2min
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed: 128.0min finished
# 100%|██████████| 4/4 [2:27:28<00:00, 2212.02s/it]

# %%
X_transf = np.concatenate((X_train_transf, X_test_transf), axis=0)
y = y_train.append(y_test).reset_index(drop=True)

fig, ax = plt.subplots(2, 2, figsize=(10,10))
axes = [ax[0,0], ax[0,1], ax[1,0], ax[1,1]]

for i, m in enumerate(best_estimators.keys()):
    train_sizes, train_scores, test_scores = learning_curve(best_estimators[m],
                                                            X_transf,
                                                            y,
                                                            train_sizes=np.linspace(0.1, 0.9, 9),
                                                            cv=tscv,
                                                            scoring='precision',
                                                            n_jobs=-1)

    sns.lineplot(train_sizes, train_scores.mean(axis=1), markers=True, ax=axes[i]).set_title(m)
    sns.lineplot(train_sizes, test_scores.mean(axis=1), markers=True, ax=axes[i])
    axes[i].legend(['train', 'test']);

# %%
precision_scores = {}
precision_scores['train precision'] = []
precision_scores['val precision'] = []
precision_scores['test precision'] = []

for m in best_estimators.keys(): 
    best = best_estimators[m]
    results = cross_validate(best,
                             X_train_transf,
                             y_train,
                             cv=tscv,
                             scoring='precision',
                             return_train_score=True)

    train_score = results['train_score'].mean()
    val_score = results['test_score'].mean()
    test_score = precision_score(y_test, best.predict(X_test_transf))

    precision_scores['train precision'].append(round(100 * train_score, 4))
    precision_scores['val precision'].append(round(100 * val_score, 4))
    precision_scores['test precision'].append(round(100 * test_score, 4))

# %%
precision_scores_df = pd.DataFrame(precision_scores, index=list(best_estimators.keys()))
precision_scores_df
# Out:
#       train precision  val precision  test precision
# logr          73.5025        58.8797         52.1739
# svm           67.2957        64.0531         61.6438
# lgbm          83.5835        75.3158         65.0000
# xgb           73.2201        66.6777         62.7119

# %%
clf = best_estimators['lgbm']
y_pred_proba = clf.predict_proba(X_test_transf)[:, 1]

risk_averse_threshold = 0.51
risk_neutral_threshold = 0.5
risk_lover_threshold = 0.49

precision_averse = '{:.3f}%'.format(100 * precision_score(y_test, y_pred_proba >= risk_averse_threshold))
precision_neutral = '{:.3f}%'.format(100 * precision_score(y_test, y_pred_proba >= risk_neutral_threshold))
precision_lover = '{:.3f}%'.format(100 * precision_score(y_test, y_pred_proba >= risk_lover_threshold))

recall_averse = '{:.3f}%'.format(100 * recall_score(y_test, y_pred_proba >= risk_averse_threshold))
recall_neutral = '{:.3f}%'.format(100 * recall_score(y_test, y_pred_proba >= risk_neutral_threshold))
recall_lover = '{:.3f}%'.format(100 * recall_score(y_test, y_pred_proba >= risk_lover_threshold))

display(pd.DataFrame([[precision_averse, recall_averse],
                      [precision_neutral, recall_neutral],
                      [precision_lover, recall_lover]],
                     columns=['precision', 'recall'],
                     index=['risk averse', 'risk neutral', 'risk lover']))
# Out:
#              precision   recall
# risk averse    65.000%   9.155%
# risk neutral   65.000%   9.155%
# risk lover     60.417%  61.268%

# %%
sns.distplot(full_test_df['bullish proba'], norm_hist=True);

# %%
full_test_df = full_df.iloc[test_idx]
full_test_df['bullish proba'] = y_pred_proba

full_test_df['risk averse pred'] = (y_pred_proba >= risk_averse_threshold).astype(int)
full_test_df['risk neutral pred'] = (y_pred_proba >= risk_neutral_threshold).astype(int)
full_test_df['risk lover pred'] = (y_pred_proba >= risk_lover_threshold).astype(int)

risk_color_ls = {}
risk_color_ls['averse'] = []
risk_color_ls['neutral'] = []
risk_color_ls['lover'] = []

for risk in risk_color_ls.keys():
    for i in test_idx:
        if (full_test_df.loc[i, f'risk {risk} pred'] == full_test_df.loc[i, 'bullish']) &\
        (full_test_df.loc[i, 'risk averse pred'] == 1):
            risk_color_ls[risk].append('green')
        elif (full_test_df.loc[i, f'risk {risk} pred'] == full_test_df.loc[i, 'bullish']) &\
        (full_test_df.loc[i, 'risk averse pred'] == 0):
            risk_color_ls[risk].append('red')
        elif full_test_df.loc[i, f'risk {risk} pred'] != full_test_df.loc[i, 'bullish']:
            risk_color_ls[risk].append('black')
    full_test_df[f'risk {risk} color'] = risk_color_ls[risk]

# %%
fig = make_subplots(rows=2, cols=1, row_heights=[0.8, 0.2])

fig.add_trace(go.Candlestick(x=full_test_df['date'],
                             open=full_test_df['open'],
                             high=full_test_df['high'],
                             low=full_test_df['low'],
                             close=full_test_df['close'],
                             name='candlestick'),
              row=1, col=1)

fig.update_layout(xaxis_rangeslider_visible=False)

fig.add_trace(go.Bar(x=full_test_df['date'],
                     y=full_test_df['bullish proba'],
                     name='up/down',
                     marker_color=full_test_df['risk neutral color']),
              row=2, col=1)
# fig.update_layout(yaxis=dict(range=[.48, .52]))

fig.add_trace(go.Scatter(x=full_test_df['date'],
                         y=[risk_neutral_threshold] * len(full_test_df),
                         name='risk neutral',
                         line = dict(color='royalblue', width=1, dash='dash')),
             row=2, col=1)

fig.show()
# Out:
# <div>
#
#
#             <div id="7fb872f5-6d1e-490c-be94-e6d3c928edf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7fb872f5-6d1e-490c-be94-e6d3c928edf1")) {
#                     Plotly.newPlot(
#                         '7fb872f5-6d1e-490c-be94-e6d3c928edf1',
#                         [{"close": [296.38, 297.46, 308.77, 307.02, 312.21, 312.89, 321.35, 317.22, 307.51, 305.8, 312.84, 311.81, 308.17, 303.77, 307.88, 305.64, 302.56, 291.23, 294.71, 298.77, 297.86, 314.74, 319.88, 294.79, 285.36, 276.54, 276.24, 276.59, 284.14, 290.92, 283.36, 288.96, 289.96, 275.43, 269.49, 267.47, 273.6, 274.02, 264.53, 260.42, 267.77, 274.83, 278.62, 279.86, 289.18, 285.88, 291.81, 267.78, 274.96, 273.2, 272.31, 276.06, 268.42, 267.7, 266.38, 273.36, 271.23, 273.26, 262.75, 263.9, 258.66, 247.63, 235.14, 241.47, 238.69, 234.01, 244.1, 255.03, 255.34, 247.06, 244.84, 241.98, 239.52, 227.01, 232.31, 231.95, 228.33, 211.03, 205.36, 205.08, 192.73, 195.49, 190.63, 188.7, 189.86, 188.22, 185.16, 178.97, 193.6, 196.59, 205.95, 204.5, 212.88, 217.1, 209.26, 213.91, 214.92, 225.03, 224.74, 226.43, 219.62, 221.86, 223.64, 219.76, 219.27, 222.84, 223.46, 227.17, 224.55, 234.9, 233.1, 230.34, 230.06, 238.92, 238.6, 245.08, 253.5, 252.38, 254.86, 253.54, 258.18, 255.68, 260.17, 264.88, 228.82, 228.04, 235.77, 242.26, 241.61, 233.85, 234.34, 228.32, 230.75, 233.42, 238.3, 235.01, 229.01, 235.0, 219.62, 215.64, 219.94, 226.83, 
337.46, 349.19, 350.37, 356.33, 353.84, 352.8, 353.15, 359.99, 361.2, 360.84, 341.0, 344.57, 335.5, 333.93, 331.26, 336.38, 337.91, 337.86, 334.42, 338.86, 344.45, 350.73, 357.19, 362.74, 365.21, 383.61, 385.5, 395.22, 406.85, 413.0, 422.01, 425.47, 433.48, 435.31, 429.0, 421.29, 430.7, 454.0, 451.56, 471.63, 498.49, 498.8, 484.94, 525.63, 547.41, 537.84, 514.46, 515.67, 548.58, 594.5, 582.0, 57 ...

# %%
fig = make_subplots(rows=2, cols=1, row_heights=[0.8, 0.2])

fig.add_trace(go.Candlestick(x=full_test_df['date'],
                             open=full_test_df['open'],
                             high=full_test_df['high'],
                             low=full_test_df['low'],
                             close=full_test_df['close'],
                             name='candlestick'),
              row=1, col=1)

fig.update_layout(xaxis_rangeslider_visible=False)

fig.add_trace(go.Bar(x=full_test_df['date'],
                     y=full_test_df['bullish proba'],
                     name='up/down',
                     marker_color=full_test_df['risk averse color']),
              row=2, col=1)

fig.add_trace(go.Scatter(x=full_test_df['date'],
                         y=[risk_averse_threshold] * len(full_test_df),
                         name='risk averse',
                         line = dict(color='royalblue', width=2, dash='dash')),
             row=2, col=1)

fig.show()
# Out:
# <div>
#
#
#             <div id="39bf187f-87e2-4397-9c50-f6da8dd5a16f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39bf187f-87e2-4397-9c50-f6da8dd5a16f")) {
#                     Plotly.newPlot(
#                         '39bf187f-87e2-4397-9c50-f6da8dd5a16f',
#                         [{"close": [296.38, 297.46, 308.77, 307.02, 312.21, 312.89, 321.35, 317.22, 307.51, 305.8, 312.84, 311.81, 308.17, 303.77, 307.88, 305.64, 302.56, 291.23, 294.71, 298.77, 297.86, 314.74, 319.88, 294.79, 285.36, 276.54, 276.24, 276.59, 284.14, 290.92, 283.36, 288.96, 289.96, 275.43, 269.49, 267.47, 273.6, 274.02, 264.53, 260.42, 267.77, 274.83, 278.62, 279.86, 289.18, 285.88, 291.81, 267.78, 274.96, 273.2, 272.31, 276.06, 268.42, 267.7, 266.38, 273.36, 271.23, 273.26, 262.75, 263.9, 258.66, 247.63, 235.14, 241.47, 238.69, 234.01, 244.1, 255.03, 255.34, 247.06, 244.84, 241.98, 239.52, 227.01, 232.31, 231.95, 228.33, 211.03, 205.36, 205.08, 192.73, 195.49, 190.63, 188.7, 189.86, 188.22, 185.16, 178.97, 193.6, 196.59, 205.95, 204.5, 212.88, 217.1, 209.26, 213.91, 214.92, 225.03, 224.74, 226.43, 219.62, 221.86, 223.64, 219.76, 219.27, 222.84, 223.46, 227.17, 224.55, 234.9, 233.1, 230.34, 230.06, 238.92, 238.6, 245.08, 253.5, 252.38, 254.86, 253.54, 258.18, 255.68, 260.17, 264.88, 228.82, 228.04, 235.77, 242.26, 241.61, 233.85, 234.34, 228.32, 230.75, 233.42, 238.3, 235.01, 229.01, 235.0, 219.62, 215.64, 219.94, 226.83, 225.86, 220.83, 222.15, 211.4, 215.0, 214.08, 215.59, 221.71, 225.61, 225.01, 220.68, 229.58, 227.45, 231.79, 235.54, 247.1, 245.87, 245.2, 242.81, 244.79, 243.49, 246.6, 240.62, 241.23, 223.21, 228.7, 242.56, 242.13
# %%
fig = make_subplots(rows=2, cols=1, row_heights=[0.8, 0.2])

fig.add_trace(go.Candlestick(x=full_test_df['date'],
                             open=full_test_df['open'],
                             high=full_test_df['high'],
                             low=full_test_df['low'],
                             close=full_test_df['close'],
                             name='candlestick'),
              row=1, col=1)

fig.update_layout(xaxis_rangeslider_visible=False)

fig.add_trace(go.Bar(x=full_test_df['date'],
                     y=full_test_df['bullish proba'],
                     name='up/down',
                     marker_color=full_test_df['risk lover color']),
              row=2, col=1)

fig.add_trace(go.Scatter(x=full_test_df['date'],
                         y=[risk_lover_threshold] * len(full_test_df),
                         name='risk lover',
                         line = dict(color='royalblue', width=2, dash='dash')),
             row=2, col=1)

fig.show()
# Out:
# <div>
#
#
#             <div id="3da8147c-2b69-49c1-9134-e610d113b261" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3da8147c-2b69-49c1-9134-e610d113b261")) {
#                     Plotly.newPlot(
#                         '3da8147c-2b69-49c1-9134-e610d113b261',
#                         [{"close": [296.38, 297.46, 308.77, 307.02, 312.21, 312.89, 321.35, 317.22, 307.51, 305.8, 312.84, 311.81, 308.17, 303.77, 307.88, 305.64, 302.56, 291.23, 294.71, 298.77, 297.86, 314.74, 319.88, 294.79, 285.36, 276.54, 276.24, 276.59, 284.14, 290.92, 283.36, 288.96, 289.96, 275.43, 269.49, 267.47, 273.6, 274.02, 264.53, 260.42, 267.77, 274.83, 278.62, 279.86, 289.18, 285.88, 291.81, 267.78, 274.96, 273.2, 272.31, 276.06, 268.42, 267.7, 266.38, 273.36, 271.23, 273.26, 262.75, 263.9, 258.66, 247.63, 235.14, 241.47, 238.69, 234.01, 244.1, 255.03, 255.34, 247.06, 244.84, 241.98, 239.52, 227.01, 232.31, 231.95, 228.33, 211.03, 205.36, 205.08, 192.73, 195.49, 190.63, 188.7, 189.86, 188.22, 185.16, 178.97, 193.6, 196.59, 205.95, 204.5, 212.88, 217.1, 209.26, 213.91, 214.92, 225.03, 224.74, 226.43, 219.62, 221.86, 223.64, 219.76, 219.27, 222.84, 223.46, 227.17, 224.55, 234.9, 233.1, 230.34, 230.06, 238.92, 238.6, 245.08, 253.5, 252.38, 254.86, 253.54, 258.18, 255.68, 260.17, 264.88, 228.82, 228.04, 235.77, 242.26, 241.61, 233.85, 234.34, 228.32, 230.75, 233.42, 238.3, 235.01, 229.01, 235.0, 219.62, 215.64, 219.94, 226.83, 225.86, 220.83, 222.15, 211.4, 215.0, 214.08, 215.59, 221.71, 225.61, 225.01, 220.68, 229.58, 227.45, 231.79, 235.54, 247.1, 245.87, 245.2, 242.81, 244.79, 243.49, 246.6, 240.62, 241.23, 223.21, 228.7, 242.56, 242.13, 240.87, 244.69, 243.13, 233.03, 231.43, 237.72, 240.05, 244.53, 244.74, 247.89, 256.96, 257.89, 259.75, 261.97, 256.95, 253.5, 255.58, 254.68, 299.68, 328.13, 327.71, 316.22, 315.01, 314.92, 